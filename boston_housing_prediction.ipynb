# %% [markdown]
# <a href="https://colab.research.google.com/github/chase-xu/machine-learning-projects/blob/master/boston_housing_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
housing_data = pd.read_csv("/content/drive/My Drive/Colab Notebooks/machine-learning-projects/BostonHousing/HousingData.csv")
housing_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222     18.7  396.90    NaN  36.2
#
# [5 rows x 14 columns]

# %%
sns.pairplot(housing_data)

# %%
sns.heatmap(housing_data)

# %%
housing_data.count() / len(housing_data)
# Out:
# CRIM       0.960474
# ZN         0.960474
# INDUS      0.960474
# CHAS       0.960474
# NOX        1.000000
# RM         1.000000
# AGE        0.960474
# DIS        1.000000
# RAD        1.000000
# TAX        1.000000
# PTRATIO    1.000000
# B          1.000000
# LSTAT      0.960474
# MEDV       1.000000
# dtype: float64
